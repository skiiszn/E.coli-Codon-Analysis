# %%
import numpy as np
import pandas as pd
from itertools import product
import os
from Bio import SeqIO

# %%
nucleotides = ['A', 'C', 'G', 'T']
combinations_of_3 = list(product(nucleotides, repeat=3))

kolone = [''.join(combination) for combination in combinations_of_3]

# %%
# Sa greskom
genoms = ['NC_008563','NC_004431','NC_002655','NC_017632','NC_017641']

# %%
genoms = ['NC_017626', 'NC_017627', 'NC_013364', 'NC_013365', 'NC_013366', 'NC_013361', 'NC_013369', 
          'NC_013353', 'NC_013354', 'NC_018650', 'NC_018654', 'NC_018661', 'NC_018662', 'NC_018658', 
          'NC_018659', 'NC_018666', 'NC_008253', 'NC_011748', 'NC_017631', 'NC_008563', 'NC_009837', 
          'NC_009838', 'NC_020163', 'NC_010468', 'NC_012892', 'NC_012971', 'NC_013941', 'NC_017646', 
          'NC_004431', 'NC_017625', 'NC_017638', 'NC_011601', 'NC_009786', 'NC_009788', 'NC_009790', 
          'NC_009801', 'NC_011353', 'NC_011745', 'NC_002655', 'NC_007414', 'NC_017633', 'NC_012947', 
          'NC_009800', 'NC_011741', 'NC_011750', 'NC_017628', 'NC_007779', 'NC_010473', 'NC_012759', 
          'NC_020518', 'NC_000913', 'NC_016902', 'NC_016904', 'NC_017660', 'NC_011993', 'NC_022364', 
          'NC_017644', 'NC_017634', 'NC_017659', 'NC_017663', 'NC_022370', 'NC_012967', 'NC_017656', 
          'NC_017657', 'NC_011742', 'NC_011747', 'NC_011415', 'NC_011419', 'NC_013654', 'NC_013655', 
          'NC_010488', 'NC_010498', 'NC_002128', 'NC_002695', 'NC_013008', 'NC_013010', 'NC_017630', 
          'NC_017632', 'NC_011739', 'NC_011749', 'NC_011751', 'NC_017639', 'NC_017641', 'NC_017642', 
          'NC_017645', 'NC_007941', 'NC_007946', 'NC_017635', 'NC_017637', 'NC_017664', 'NC_017665', 
          'NC_017906', 'NC_017907', 'NC_017652', 'NC_017651']

# %% [markdown]
# # Brojanje kodona za PAI ostrva

# %%
for genom in genoms:

    fasta_file = f"{genom}/{genom}.fasta"
    sequences = SeqIO.parse(fasta_file, "fasta")

    if os.path.exists(f"{genom}/patogena_ostrva.csv"):
        pai_ostrva = pd.read_csv(f"{genom}/patogena_ostrva.csv")

        niska = None
        for record in sequences:
            niska = record.seq

        for index, row in pai_ostrva.iterrows():
            i = row['Start']
            while row['End'] != i + 2:
                kodon = niska[i:i+3]
                if kodon in pai_ostrva.columns:
                    pai_ostrva.at[index, kodon] += 1
                else:
                    print(f"Kodon {kodon} nije validan.")
                    break
                i += 1
        pai_ostrva.to_csv(f"{genom}/patogena_ostrva.csv", index=False)
        print(f"Zavrsen {genom}.")
    else:
        print("Nema PAI ostrva.")
# Out:
# Zavrsen NC_017626.
# Zavrsen NC_017627.
# Zavrsen NC_013364.
# Zavrsen NC_013365.
# Zavrsen NC_013366.
# Zavrsen NC_013361.
# Zavrsen NC_013369.
# Zavrsen NC_013353.
# Zavrsen NC_013354.
# Zavrsen NC_018650.
# Zavrsen NC_018654.
# Zavrsen NC_018661.
# Zavrsen NC_018662.
# Zavrsen NC_018658.
# Zavrsen NC_018659.
# Zavrsen NC_018666.
# Zavrsen NC_008253.
# Zavrsen NC_011748.
# Zavrsen NC_017631.
# Kodon CAY nije validan.
# Kodon CGR nije validan.
# Kodon CAY nije validan.
# Kodon CGR nije validan.
# Zavrsen NC_008563.
# Zavrsen NC_009837.
# Zavrsen NC_009838.
# Zavrsen NC_020163.
# Zavrsen NC_010468.
# Zavrsen NC_012892.
# Zavrsen NC_012971.
# Zavrsen NC_013941.
# Zavrsen NC_017646.
# Kodon CAK nije validan.
# Kodon GCM nije validan.
# Kodon AGM nije validan.
# Kodon CGW nije validan.
# Zavrsen NC_004431.
# Zavrsen NC_017625.
# Zavrsen NC_017638.
# Zavrsen NC_011601.
# Nema PAI ostrva.
# Nema PAI ostrva.
# Zavrsen NC_009790.
# Zavrsen NC_009801.
# Zavrsen NC_011353.
# Zavrsen NC_011745.
# Kodon CCY nije validan.
# Kodon AAR nije validan.
# Kodon AAR nije validan.
# Kodon ACN nije validan.
# Kodon CCM nije validan.
# Kodon AAK nije validan.
# Kodon GCW nije validan.
# Kodon TGY nije validan.
# Kodon AAR nije validan.
# Kodon AAR nije validan.
# Kodon AAK nije validan.
# Zavrsen NC_002655.
# Zavrsen NC_007414.
# Zavrsen NC_017633.
# Zavrsen NC_012947.
# Zavrsen NC_009800.
# Zavrsen NC_011741.
# Zavrsen NC_011750.
# Zavrsen NC_017628.
# Zavrsen NC_007779.
# Zavrsen NC_010473.
# Zavrsen NC_012759.
# Zavrsen NC_020518.
# Zavrsen NC_000913.
# Zavrsen NC_016902.
# Zavrsen NC_016904.
# Zavrsen NC_017660.
# Zavrsen NC_011993.
# Zavrsen NC_022364.
# Zavrsen NC_017644.
# Zavrsen NC_017634.
# Zavrsen NC_017659.
# Zavrsen NC_017663.
# Zavrsen NC_022370.
# Zavrsen NC_012967.
# Zavrsen NC_017656.
# Zavrsen NC_017657.
# Zavrsen NC_011742.
# Zavrsen NC_011747.
# Zavrsen NC_011415.
# Zavrsen NC_011419.
# Zavrsen NC_013654.
# Zavrsen NC_013655.
# Zavrsen NC_010488.
# Zavrsen NC_010498.
# Zavrsen NC_002128.
# Zavrsen NC_002695.
# Zavrsen NC_013008.
# Zavrsen NC_013010.
# Zavrsen NC_017630.
# Kodon TAY nije validan.
# Zavrsen NC_017632.
# Nema PAI ostrva.
# Zavrsen NC_011749.
# Zavrsen NC_011751.
# Nema PAI ostrva.
# Kodon GTR nije validan.
# Kodon GGR nije validan.
# Zavrsen NC_017641.
# Zavrsen NC_017642.
# Zavrsen NC_017645.
# Zavrsen NC_007941.
# Zavrsen NC_007946.
# Zavrsen NC_017635.
# Zavrsen NC_017637.
# Zavrsen NC_017664.
# Zavrsen NC_017665.
# Zavrsen NC_017906.
# Zavrsen NC_017907.
# Zavrsen NC_017652.
# Zavrsen NC_017651.
