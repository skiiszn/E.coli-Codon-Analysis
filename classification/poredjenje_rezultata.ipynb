# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %store -r knn_best_accuracy
# %store -r dtc_best_accuracy
# %store -r rfc_best_accuracy
# %store -r xgb_best_accuracy
# %store -r nn_best_accuracy

# %%
models = ['knn', 'dtc', 'rfc', 'xgb', 'nn']
accuracies = [knn_best_accuracy, dtc_best_accuracy, rfc_best_accuracy, xgb_best_accuracy, nn_best_accuracy]
colors = ['orange', 'pink', 'purple', 'brown', 'gray']

# %%
plt.bar(models, accuracies, color=colors)
plt.title('Poređenje tačnosti svih modela')
plt.ylim(0.7, 0.9)

plt.savefig('poredjenje_svih_modela.png')
plt.tight_layout()
plt.show()

# %%
# %store -r classification_rep_knn_basic
# %store -r classification_rep_knn_SMOTE

# %%
# %store -r classification_rep_dtc_basic
# %store -r classification_rep_dtc_SMOTE
# %store -r classification_rep_dtc_cw

# %%
# %store -r classification_rep_rf_basic
# %store -r classification_rep_rf_SMOTE
# %store -r classification_rep_rf_cw

# %%
# %store -r classification_rep_xgb_basic
# %store -r classification_rep_xgb_SMOTE

# %%
# %store -r xgb_categories_basic
# %store -r xgb_categories_SMOTE

# %%
# %store -r classification_rep_nn_basic
# %store -r classification_rep_nn_SMOTE
# %store -r classification_rep_nn_cw

# %%
# %store -r nn_categories_basic
# %store -r nn_categories_SMOTE
# %store -r nn_categories_cw

# %%
classification_rep_dtc_basic
# Out:
# {'C': {'precision': 0.8426966292134831,
#   'recall': 0.9146341463414634,
#   'f1-score': 0.8771929824561403,
#   'support': 82.0},
#  'K': {'precision': 0.75,
#   'recall': 0.6,
#   'f1-score': 0.6666666666666665,
#   'support': 25.0},
#  'N': {'precision': 0.7777777777777778,
#   'recall': 0.84,
#   'f1-score': 0.8076923076923077,
#   'support': 25.0},
#  'P': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 4.0},
#  'R': {'precision': 0.6,
#   'recall': 0.5625,
#   'f1-score': 0.5806451612903225,
#   'support': 16.0},
#  'accuracy': 0.7894736842105263,
#  'macro avg': {'precision': 0.5940948813982522,
#   'recall': 0.5834268292682927,
#   'f1-score': 0.5864394236210875,
#   'support': 152.0},
#  'weighted avg': {'precision': 0.7690497897365135,
#   'recall': 0.7894736842105263,
#   'f1-score': 0.7768363256646251,
#   'support': 152.0}}

# %% [markdown]
# ## Preciznost

# %% [markdown]
# **Preciznost cPai**

# %%
plt.rcParams.update({'font.size': 16})
fig = plt.figure(figsize=(12, 6))
xgb_class_basic = f"{xgb_categories_basic[0].index('C')}.0"
xgb_class_SMOTE = f"{xgb_categories_SMOTE[0].index('C')}.0"
nn_class_basic = f"{nn_categories_basic[0].index('C')}"
nn_class_SMOTE = f"{nn_categories_SMOTE[0].index('C')}"
nn_class_cw = f"{nn_categories_cw[0].index('C')}"


plt.bar(['knn_obican', 'knn_SMOTE', 'dtc_obican', 'dtc_SMOTE', 'dtc_tezine', 'rf_obican', 'rf_SMOTE', 'rf_tezine', 'xgb_obican', 'xgb_SMOTE', 'nn_obican', 'nn_SMOTE', 'nn_tezine'],
        [
            classification_rep_knn_basic['C']['precision'], classification_rep_knn_SMOTE['C']['precision'],
            classification_rep_dtc_basic['C']['precision'], classification_rep_dtc_SMOTE['C']['precision'], classification_rep_dtc_cw['C']['precision'],
            classification_rep_rf_basic['C']['precision'], classification_rep_rf_SMOTE['C']['precision'], classification_rep_rf_cw['C']['precision'],
            classification_rep_xgb_basic[xgb_class_basic]['precision'], classification_rep_xgb_SMOTE[xgb_class_SMOTE]['precision'],
            classification_rep_nn_basic[nn_class_basic]['precision'], classification_rep_nn_SMOTE[nn_class_SMOTE]['precision'], classification_rep_nn_cw[nn_class_cw]['precision']
        ],
       color = [
           'greenyellow', 'greenyellow',
           'lawngreen', 'lawngreen', 'lawngreen',
           'limegreen', 'limegreen', 'limegreen',
           'green', 'green',
           'darkgreen', 'darkgreen', 'darkgreen'
       ])

plt.xticks(rotation=90)
plt.ylim(0.7, 1)
plt.title('Preciznost klase ' + r"$\bf{" + 'cPai' + "}$" + ' na razlicitim skupovima')
plt.tight_layout()
plt.savefig('preciznost_cpai.png')
plt.show()

# %% [markdown]
# **Preciznost nPai**

# %%
plt.rcParams.update({'font.size': 16})
fig = plt.figure(figsize=(12, 6))
xgb_class_basic = f"{xgb_categories_basic[0].index('N')}.0"
xgb_class_SMOTE = f"{xgb_categories_SMOTE[0].index('N')}.0"
nn_class_basic = f"{nn_categories_basic[0].index('N')}"
nn_class_SMOTE = f"{nn_categories_SMOTE[0].index('N')}"
nn_class_cw = f"{nn_categories_cw[0].index('N')}"


plt.bar(['knn_obican', 'knn_SMOTE', 'dtc_obican', 'dtc_SMOTE', 'dtc_tezine', 'rf_obican', 'rf_SMOTE', 'rf_tezine', 'xgb_obican', 'xgb_SMOTE', 'nn_obican', 'nn_SMOTE', 'nn_tezine'],
        [
            classification_rep_knn_basic['N']['precision'], classification_rep_knn_SMOTE['N']['precision'],
            classification_rep_dtc_basic['N']['precision'], classification_rep_dtc_SMOTE['N']['precision'], classification_rep_dtc_cw['N']['precision'],
            classification_rep_rf_basic['N']['precision'], classification_rep_rf_SMOTE['N']['precision'], classification_rep_rf_cw['N']['precision'],
            classification_rep_xgb_basic[xgb_class_basic]['precision'], classification_rep_xgb_SMOTE[xgb_class_SMOTE]['precision'],
            classification_rep_nn_basic[nn_class_basic]['precision'], classification_rep_nn_SMOTE[nn_class_SMOTE]['precision'], classification_rep_nn_cw[nn_class_cw]['precision']
        ],
       color = [
           'tomato', 'tomato',
           'orangered', 'orangered', 'orangered',
           'red', 'red', 'red',
           'firebrick', 'firebrick',
           'maroon', 'maroon', 'maroon'
       ])

plt.xticks(rotation=90)
plt.ylim(0.7, 1)
plt.title('Preciznost klase ' + r"$\bf{" + 'nPai' + "}$" + ' na razlicitim skupovima')
plt.tight_layout()
plt.savefig('preciznost_npai.png')
plt.show()

# %% [markdown]
# **Preciznost pai**

# %%
plt.rcParams.update({'font.size': 16})
fig = plt.figure(figsize=(12, 6))
xgb_class_basic = f"{xgb_categories_basic[0].index('P')}.0"
xgb_class_SMOTE = f"{xgb_categories_SMOTE[0].index('P')}.0"
nn_class_basic = f"{nn_categories_basic[0].index('P')}"
nn_class_SMOTE = f"{nn_categories_SMOTE[0].index('P')}"
nn_class_cw = f"{nn_categories_cw[0].index('P')}"


plt.bar(['knn_obican', 'knn_SMOTE', 'dtc_obican', 'dtc_SMOTE', 'dtc_tezine', 'rf_obican', 'rf_SMOTE', 'rf_tezine', 'xgb_obican', 'xgb_SMOTE', 'nn_obican', 'nn_SMOTE', 'nn_tezine'],
        [
            classification_rep_knn_basic['P']['precision'], classification_rep_knn_SMOTE['P']['precision'],
            classification_rep_dtc_basic['P']['precision'], classification_rep_dtc_SMOTE['P']['precision'], classification_rep_dtc_cw['P']['precision'],
            classification_rep_rf_basic['P']['precision'], classification_rep_rf_SMOTE['P']['precision'], classification_rep_rf_cw['P']['precision'],
            classification_rep_xgb_basic[xgb_class_basic]['precision'], classification_rep_xgb_SMOTE[xgb_class_SMOTE]['precision'],
            classification_rep_nn_basic[nn_class_basic]['precision'], classification_rep_nn_SMOTE[nn_class_SMOTE]['precision'], classification_rep_nn_cw[nn_class_cw]['precision']
        ],
       color = [
           'royalblue', 'royalblue',
           'blue', 'blue', 'blue',
           'navy', 'navy', 'navy',
           'indigo', 'indigo',
           'purple', 'purple', 'purple'
       ])

plt.xticks(rotation=90)
plt.ylim(0, 1)
plt.title('Preciznost klase ' + r"$\bf{" + 'pai' + "}$" + ' na razlicitim skupovima')
plt.tight_layout()
plt.savefig('preciznost_pai.png')
plt.show()

# %% [markdown]
# **Preciznost kompletna sekvenca**

# %%
plt.rcParams.update({'font.size': 16})
fig = plt.figure(figsize=(12, 6))
xgb_class_basic = f"{xgb_categories_basic[0].index('K')}.0"
xgb_class_SMOTE = f"{xgb_categories_SMOTE[0].index('K')}.0"
nn_class_basic = f"{nn_categories_basic[0].index('K')}"
nn_class_SMOTE = f"{nn_categories_SMOTE[0].index('K')}"
nn_class_cw = f"{nn_categories_cw[0].index('K')}"


plt.bar(['knn_obican', 'knn_SMOTE', 'dtc_obican', 'dtc_SMOTE', 'dtc_tezine', 'rf_obican', 'rf_SMOTE', 'rf_tezine', 'xgb_obican', 'xgb_SMOTE', 'nn_obican', 'nn_SMOTE', 'nn_tezine'],
        [
            classification_rep_knn_basic['K']['precision'], classification_rep_knn_SMOTE['K']['precision'],
            classification_rep_dtc_basic['K']['precision'], classification_rep_dtc_SMOTE['K']['precision'], classification_rep_dtc_cw['K']['precision'],
            classification_rep_rf_basic['K']['precision'], classification_rep_rf_SMOTE['K']['precision'], classification_rep_rf_cw['K']['precision'],
            classification_rep_xgb_basic[xgb_class_basic]['precision'], classification_rep_xgb_SMOTE[xgb_class_SMOTE]['precision'],
            classification_rep_nn_basic[nn_class_basic]['precision'], classification_rep_nn_SMOTE[nn_class_SMOTE]['precision'], classification_rep_nn_cw[nn_class_cw]['precision']
        ],
       color = [
           'whitesmoke', 'whitesmoke',
           'silver', 'silver', 'silver',
           'gray', 'gray', 'gray',
           'dimgrey', 'dimgrey',
           'black', 'black', 'black'
       ])

plt.xticks(rotation=90)
plt.ylim(0.4, 1)
plt.title('Preciznost klase ' + r"$\bf{" + 'kompletna\_sekvenca' + "}$" + ' na razlicitim skupovima')
plt.tight_layout()
plt.savefig('preciznost_kompletna.png')
plt.show()

# %% [markdown]
# ## Odziv

# %% [markdown]
# **Odziv cPai**

# %%
plt.rcParams.update({'font.size': 16})
fig = plt.figure(figsize=(12, 6))
xgb_class_basic = f"{xgb_categories_basic[0].index('C')}.0"
xgb_class_SMOTE = f"{xgb_categories_SMOTE[0].index('C')}.0"
nn_class_basic = f"{nn_categories_basic[0].index('C')}"
nn_class_SMOTE = f"{nn_categories_SMOTE[0].index('C')}"
nn_class_cw = f"{nn_categories_cw[0].index('C')}"


plt.bar(['knn_obican', 'knn_SMOTE', 'dtc_obican', 'dtc_SMOTE', 'dtc_tezine', 'rf_obican', 'rf_SMOTE', 'rf_tezine', 'xgb_obican', 'xgb_SMOTE', 'nn_obican', 'nn_SMOTE', 'nn_tezine'],
        [
            classification_rep_knn_basic['C']['recall'], classification_rep_knn_SMOTE['C']['recall'],
            classification_rep_dtc_basic['C']['recall'], classification_rep_dtc_SMOTE['C']['recall'], classification_rep_dtc_cw['C']['recall'],
            classification_rep_rf_basic['C']['recall'], classification_rep_rf_SMOTE['C']['recall'], classification_rep_rf_cw['C']['recall'],
            classification_rep_xgb_basic[xgb_class_basic]['recall'], classification_rep_xgb_SMOTE[xgb_class_SMOTE]['recall'],
            classification_rep_nn_basic[nn_class_basic]['recall'], classification_rep_nn_SMOTE[nn_class_SMOTE]['recall'], classification_rep_nn_cw[nn_class_cw]['recall']
        ],
       color = [
           'greenyellow', 'greenyellow',
           'lawngreen', 'lawngreen', 'lawngreen',
           'limegreen', 'limegreen', 'limegreen',
           'green', 'green',
           'darkgreen', 'darkgreen', 'darkgreen'
       ])

plt.xticks(rotation=90)
plt.ylim(0.7, 1)
plt.title('Odziv klase ' + r"$\bf{" + 'cPai' + "}$" + ' na razlicitim skupovima')
plt.tight_layout()
plt.savefig('odziv_cpai.png')
plt.show()

# %% [markdown]
# **Odziv nPai**

# %%
plt.rcParams.update({'font.size': 16})
fig = plt.figure(figsize=(12, 6))
xgb_class_basic = f"{xgb_categories_basic[0].index('N')}.0"
xgb_class_SMOTE = f"{xgb_categories_SMOTE[0].index('N')}.0"
nn_class_basic = f"{nn_categories_basic[0].index('N')}"
nn_class_SMOTE = f"{nn_categories_SMOTE[0].index('N')}"
nn_class_cw = f"{nn_categories_cw[0].index('N')}"


plt.bar(['knn_obican', 'knn_SMOTE', 'dtc_obican', 'dtc_SMOTE', 'dtc_tezine', 'rf_obican', 'rf_SMOTE', 'rf_tezine', 'xgb_obican', 'xgb_SMOTE', 'nn_obican', 'nn_SMOTE', 'nn_tezine'],
        [
            classification_rep_knn_basic['N']['recall'], classification_rep_knn_SMOTE['N']['recall'],
            classification_rep_dtc_basic['N']['recall'], classification_rep_dtc_SMOTE['N']['recall'], classification_rep_dtc_cw['N']['recall'],
            classification_rep_rf_basic['N']['recall'], classification_rep_rf_SMOTE['N']['recall'], classification_rep_rf_cw['N']['recall'],
            classification_rep_xgb_basic[xgb_class_basic]['recall'], classification_rep_xgb_SMOTE[xgb_class_SMOTE]['recall'],
            classification_rep_nn_basic[nn_class_basic]['recall'], classification_rep_nn_SMOTE[nn_class_SMOTE]['recall'], classification_rep_nn_cw[nn_class_cw]['recall']
        ],
       color = [
           'tomato', 'tomato',
           'orangered', 'orangered', 'orangered',
           'red', 'red', 'red',
           'firebrick', 'firebrick',
           'maroon', 'maroon', 'maroon'
       ])

plt.xticks(rotation=90)
plt.ylim(0.7, 1)
plt.title('Odziv klase ' + r"$\bf{" + 'nPai' + "}$" + ' na razlicitim skupovima')
plt.tight_layout()
plt.savefig('odziv_npai.png')
plt.show()

# %% [markdown]
# **Odziv pai**

# %%
plt.rcParams.update({'font.size': 16})
fig = plt.figure(figsize=(12, 6))
xgb_class_basic = f"{xgb_categories_basic[0].index('P')}.0"
xgb_class_SMOTE = f"{xgb_categories_SMOTE[0].index('P')}.0"
nn_class_basic = f"{nn_categories_basic[0].index('P')}"
nn_class_SMOTE = f"{nn_categories_SMOTE[0].index('P')}"
nn_class_cw = f"{nn_categories_cw[0].index('P')}"


plt.bar(['knn_obican', 'knn_SMOTE', 'dtc_obican', 'dtc_SMOTE', 'dtc_tezine', 'rf_obican', 'rf_SMOTE', 'rf_tezine', 'xgb_obican', 'xgb_SMOTE', 'nn_obican', 'nn_SMOTE', 'nn_tezine'],
        [
            classification_rep_knn_basic['P']['recall'], classification_rep_knn_SMOTE['P']['recall'],
            classification_rep_dtc_basic['P']['recall'], classification_rep_dtc_SMOTE['P']['recall'], classification_rep_dtc_cw['P']['recall'],
            classification_rep_rf_basic['P']['recall'], classification_rep_rf_SMOTE['P']['recall'], classification_rep_rf_cw['P']['recall'],
            classification_rep_xgb_basic[xgb_class_basic]['recall'], classification_rep_xgb_SMOTE[xgb_class_SMOTE]['recall'],
            classification_rep_nn_basic[nn_class_basic]['recall'], classification_rep_nn_SMOTE[nn_class_SMOTE]['recall'], classification_rep_nn_cw[nn_class_cw]['recall']
        ],
       color = [
           'royalblue', 'royalblue',
           'blue', 'blue', 'blue',
           'navy', 'navy', 'navy',
           'indigo', 'indigo',
           'purple', 'purple', 'purple'
       ])

plt.xticks(rotation=90)
plt.ylim(0, 1)
plt.title('Odziv klase ' + r"$\bf{" + 'pai' + "}$" + ' na razlicitim skupovima')
plt.tight_layout()
plt.savefig('odziv_pai.png')
plt.show()

# %% [markdown]
# **Odziv kompletna sekvenca**

# %%
plt.rcParams.update({'font.size': 16})
fig = plt.figure(figsize=(12, 6))
xgb_class_basic = f"{xgb_categories_basic[0].index('K')}.0"
xgb_class_SMOTE = f"{xgb_categories_SMOTE[0].index('K')}.0"
nn_class_basic = f"{nn_categories_basic[0].index('K')}"
nn_class_SMOTE = f"{nn_categories_SMOTE[0].index('K')}"
nn_class_cw = f"{nn_categories_cw[0].index('K')}"


plt.bar(['knn_obican', 'knn_SMOTE', 'dtc_obican', 'dtc_SMOTE', 'dtc_tezine', 'rf_obican', 'rf_SMOTE', 'rf_tezine', 'xgb_obican', 'xgb_SMOTE', 'nn_obican', 'nn_SMOTE', 'nn_tezine'],
        [
            classification_rep_knn_basic['K']['recall'], classification_rep_knn_SMOTE['K']['recall'],
            classification_rep_dtc_basic['K']['recall'], classification_rep_dtc_SMOTE['K']['recall'], classification_rep_dtc_cw['K']['recall'],
            classification_rep_rf_basic['K']['recall'], classification_rep_rf_SMOTE['K']['recall'], classification_rep_rf_cw['K']['recall'],
            classification_rep_xgb_basic[xgb_class_basic]['recall'], classification_rep_xgb_SMOTE[xgb_class_SMOTE]['recall'],
            classification_rep_nn_basic[nn_class_basic]['recall'], classification_rep_nn_SMOTE[nn_class_SMOTE]['recall'], classification_rep_nn_cw[nn_class_cw]['recall']
        ],
       color = [
           'whitesmoke', 'whitesmoke',
           'silver', 'silver', 'silver',
           'gray', 'gray', 'gray',
           'dimgrey', 'dimgrey',
           'black', 'black', 'black'
       ])

plt.xticks(rotation=90)
plt.ylim(0.4, 1)
plt.title('Odziv klase ' + r"$\bf{" + 'kompletna\_sekvenca' + "}$" + ' na razlicitim skupovima')
plt.tight_layout()
plt.savefig('odziv_kompletna.png')
plt.show()

# %% [markdown]
# ## F1 mera

# %% [markdown]
# **F1 mera cPai**

# %%
plt.rcParams.update({'font.size': 16})
fig = plt.figure(figsize=(12, 6))
xgb_class_basic = f"{xgb_categories_basic[0].index('C')}.0"
xgb_class_SMOTE = f"{xgb_categories_SMOTE[0].index('C')}.0"
nn_class_basic = f"{nn_categories_basic[0].index('C')}"
nn_class_SMOTE = f"{nn_categories_SMOTE[0].index('C')}"
nn_class_cw = f"{nn_categories_cw[0].index('C')}"


plt.bar(['knn_obican', 'knn_SMOTE', 'dtc_obican', 'dtc_SMOTE', 'dtc_tezine', 'rf_obican', 'rf_SMOTE', 'rf_tezine', 'xgb_obican', 'xgb_SMOTE', 'nn_obican', 'nn_SMOTE', 'nn_tezine'],
        [
            classification_rep_knn_basic['C']['f1-score'], classification_rep_knn_SMOTE['C']['f1-score'],
            classification_rep_dtc_basic['C']['f1-score'], classification_rep_dtc_SMOTE['C']['f1-score'], classification_rep_dtc_cw['C']['f1-score'],
            classification_rep_rf_basic['C']['f1-score'], classification_rep_rf_SMOTE['C']['f1-score'], classification_rep_rf_cw['C']['f1-score'],
            classification_rep_xgb_basic[xgb_class_basic]['f1-score'], classification_rep_xgb_SMOTE[xgb_class_SMOTE]['f1-score'],
            classification_rep_nn_basic[nn_class_basic]['f1-score'], classification_rep_nn_SMOTE[nn_class_SMOTE]['f1-score'], classification_rep_nn_cw[nn_class_cw]['f1-score']
        ],
       color = [
           'greenyellow', 'greenyellow',
           'lawngreen', 'lawngreen', 'lawngreen',
           'limegreen', 'limegreen', 'limegreen',
           'green', 'green',
           'darkgreen', 'darkgreen', 'darkgreen'
       ])

plt.xticks(rotation=90)
plt.ylim(0.7, 1)
plt.title('F1 mera klase ' + r"$\bf{" + 'cPai' + "}$" + ' na razlicitim skupovima')
plt.tight_layout()
plt.savefig('f1-mera_cpai.png')
plt.show()

# %% [markdown]
# **F1 mera nPai**

# %%
plt.rcParams.update({'font.size': 16})
fig = plt.figure(figsize=(12, 6))
xgb_class_basic = f"{xgb_categories_basic[0].index('N')}.0"
xgb_class_SMOTE = f"{xgb_categories_SMOTE[0].index('N')}.0"
nn_class_basic = f"{nn_categories_basic[0].index('N')}"
nn_class_SMOTE = f"{nn_categories_SMOTE[0].index('N')}"
nn_class_cw = f"{nn_categories_cw[0].index('N')}"


plt.bar(['knn_obican', 'knn_SMOTE', 'dtc_obican', 'dtc_SMOTE', 'dtc_tezine', 'rf_obican', 'rf_SMOTE', 'rf_tezine', 'xgb_obican', 'xgb_SMOTE', 'nn_obican', 'nn_SMOTE', 'nn_tezine'],
        [
            classification_rep_knn_basic['N']['f1-score'], classification_rep_knn_SMOTE['N']['f1-score'],
            classification_rep_dtc_basic['N']['f1-score'], classification_rep_dtc_SMOTE['N']['f1-score'], classification_rep_dtc_cw['N']['f1-score'],
            classification_rep_rf_basic['N']['f1-score'], classification_rep_rf_SMOTE['N']['f1-score'], classification_rep_rf_cw['N']['f1-score'],
            classification_rep_xgb_basic[xgb_class_basic]['f1-score'], classification_rep_xgb_SMOTE[xgb_class_SMOTE]['f1-score'],
            classification_rep_nn_basic[nn_class_basic]['f1-score'], classification_rep_nn_SMOTE[nn_class_SMOTE]['f1-score'], classification_rep_nn_cw[nn_class_cw]['f1-score']
        ],
       color = [
           'tomato', 'tomato',
           'orangered', 'orangered', 'orangered',
           'red', 'red', 'red',
           'firebrick', 'firebrick',
           'maroon', 'maroon', 'maroon'
       ])

plt.xticks(rotation=90)
plt.ylim(0.7, 1)
plt.title('F1 mera klase ' + r"$\bf{" + 'nPai' + "}$" + ' na razlicitim skupovima')
plt.tight_layout()
plt.savefig('f1-mera_npai.png')
plt.show()

# %% [markdown]
# **F1 mera pai**

# %%
plt.rcParams.update({'font.size': 16})
fig = plt.figure(figsize=(12, 6))
xgb_class_basic = f"{xgb_categories_basic[0].index('P')}.0"
xgb_class_SMOTE = f"{xgb_categories_SMOTE[0].index('P')}.0"
nn_class_basic = f"{nn_categories_basic[0].index('P')}"
nn_class_SMOTE = f"{nn_categories_SMOTE[0].index('P')}"
nn_class_cw = f"{nn_categories_cw[0].index('P')}"


plt.bar(['knn_obican', 'knn_SMOTE', 'dtc_obican', 'dtc_SMOTE', 'dtc_tezine', 'rf_obican', 'rf_SMOTE', 'rf_tezine', 'xgb_obican', 'xgb_SMOTE', 'nn_obican', 'nn_SMOTE', 'nn_tezine'],
        [
            classification_rep_knn_basic['P']['f1-score'], classification_rep_knn_SMOTE['P']['f1-score'],
            classification_rep_dtc_basic['P']['f1-score'], classification_rep_dtc_SMOTE['P']['f1-score'], classification_rep_dtc_cw['P']['f1-score'],
            classification_rep_rf_basic['P']['f1-score'], classification_rep_rf_SMOTE['P']['f1-score'], classification_rep_rf_cw['P']['f1-score'],
            classification_rep_xgb_basic[xgb_class_basic]['f1-score'], classification_rep_xgb_SMOTE[xgb_class_SMOTE]['f1-score'],
            classification_rep_nn_basic[nn_class_basic]['f1-score'], classification_rep_nn_SMOTE[nn_class_SMOTE]['f1-score'], classification_rep_nn_cw[nn_class_cw]['f1-score']
        ],
       color = [
           'royalblue', 'royalblue',
           'blue', 'blue', 'blue',
           'navy', 'navy', 'navy',
           'indigo', 'indigo',
           'purple', 'purple', 'purple'
       ])

plt.xticks(rotation=90)
plt.ylim(0, 1)
plt.title('F1 mera klase ' + r"$\bf{" + 'pai' + "}$" + ' na razlicitim skupovima')
plt.tight_layout()
plt.savefig('f1-mera_pai.png')
plt.show()

# %% [markdown]
# **F1 mera kompletna sekvenca**

# %%
plt.rcParams.update({'font.size': 16})
fig = plt.figure(figsize=(12, 6))
xgb_class_basic = f"{xgb_categories_basic[0].index('K')}.0"
xgb_class_SMOTE = f"{xgb_categories_SMOTE[0].index('K')}.0"
nn_class_basic = f"{nn_categories_basic[0].index('K')}"
nn_class_SMOTE = f"{nn_categories_SMOTE[0].index('K')}"
nn_class_cw = f"{nn_categories_cw[0].index('K')}"


plt.bar(['knn_obican', 'knn_SMOTE', 'dtc_obican', 'dtc_SMOTE', 'dtc_tezine', 'rf_obican', 'rf_SMOTE', 'rf_tezine', 'xgb_obican', 'xgb_SMOTE', 'nn_obican', 'nn_SMOTE', 'nn_tezine'],
        [
            classification_rep_knn_basic['K']['f1-score'], classification_rep_knn_SMOTE['K']['f1-score'],
            classification_rep_dtc_basic['K']['f1-score'], classification_rep_dtc_SMOTE['K']['f1-score'], classification_rep_dtc_cw['K']['f1-score'],
            classification_rep_rf_basic['K']['f1-score'], classification_rep_rf_SMOTE['K']['f1-score'], classification_rep_rf_cw['K']['f1-score'],
            classification_rep_xgb_basic[xgb_class_basic]['f1-score'], classification_rep_xgb_SMOTE[xgb_class_SMOTE]['f1-score'],
            classification_rep_nn_basic[nn_class_basic]['f1-score'], classification_rep_nn_SMOTE[nn_class_SMOTE]['f1-score'], classification_rep_nn_cw[nn_class_cw]['f1-score']
        ],
       color = [
           'whitesmoke', 'whitesmoke',
           'silver', 'silver', 'silver',
           'gray', 'gray', 'gray',
           'dimgrey', 'dimgrey',
           'black', 'black', 'black'
       ])

plt.xticks(rotation=90)
plt.ylim(0.4, 1)
plt.title('F1 mera klase ' + r"$\bf{" + 'kompletna\_sekvenca' + "}$" + ' na razlicitim skupovima')
plt.tight_layout()
plt.savefig('f1-mera_kompletna.png')
plt.show()
